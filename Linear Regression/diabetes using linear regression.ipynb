# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_diabetes
from mpl_toolkits import mplot3d

# %matplotlib inline

# %%
features = ['Alcohol', 'Malic Acid', 'Ash', 'Alcalinity of Acid', 'Magnesium', 'Total Phenols', 'Flavanoids', 'Nonflavanoid Phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines', 'Proline']
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', header=None, names=features)

# %%
# diabetes = load_diabetes()

# %%
# features = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
# target = pd.DataFrame(diabetes.target, columns=['TARGET'])

# %%
# data = pd.concat([features, target], axis=1)
data
# Out:
#     Alcohol  Malic Acid   Ash  Alcalinity of Acid  Magnesium  Total Phenols  \
# 1     14.23        1.71  2.43                15.6        127           2.80
# 1     13.20        1.78  2.14                11.2        100           2.65
# 1     13.16        2.36  2.67                18.6        101           2.80
# 1     14.37        1.95  2.50                16.8        113           3.85
# 1     13.24        2.59  2.87                21.0        118           2.80
# 1     14.20        1.76  2.45                15.2        112           3.27
# 1     14.39        1.87  2.45                14.6         96           2.50
# 1     14.06        2.15  2.61                17.6        121           2.60
# 1     14.83        1.64  2.17                14.0         97           2.80
# 1     13.86        1.35  2.27                16.0         98           2.98
# 1     14.10        2.16  2.30                18.0        105           2.95
# ...

# %%
print(diabetes.DESCR)
# Out:
# Diabetes dataset
# ...
#
# Notes
# -----
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# Data Set Characteristics:
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attributes:
#     :Age:
#     :Sex:
#     :Body mass index:
#     :Average blood pressure:
#     :S1:
#     :S2:
#     :S3:
#     :S4:
#     :S5:
#     :S6:
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# http://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# ...

# %%
data.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6  TARGET
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# ...

# %%
data2 = data.corr('pearson')
data2
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.173737  0.185085  0.335427  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241013  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395415  0.249777  0.261170 -0.366811
# bp      0.335427  0.241013  0.395415  1.000000  0.242470  0.185558 -0.178761
# s1      0.260061  0.035277  0.249777  0.242470  1.000000  0.896663  0.051519
# s2      0.219243  0.142637  0.261170  0.185558  0.896663  1.000000 -0.196455
# s3     -0.075181 -0.379090 -0.366811 -0.178761  0.051519 -0.196455  1.000000
# s4      0.203841  0.332115  0.413807  0.257653  0.542207  0.659817 -0.738493
# s5      0.270777  0.149918  0.446159  0.393478  0.515501  0.318353 -0.398577
# s6      0.301731  0.208133  0.388680  0.390429  0.325717  0.290600 -0.273697
# TARGET  0.187889  0.043062  0.586450  0.441484  0.212022  0.174054 -0.394789
#
# ...

# %%
abs(data2['TARGET']).sort_values(ascending=False)
# Out:
# TARGET    1.000000
# bmi       0.586450
# s5        0.565883
# bp        0.441484
# s4        0.430453
# s3        0.394789
# s6        0.382483
# s1        0.212022
# age       0.187889
# s2        0.174054
# sex       0.043062
# Name: TARGET, dtype: float64

# %%
X = data['bmi']
Y = data['TARGET']

# %%
X = np.array(X/X.mean())
Y = np.array(Y/Y.mean())

# %%
n = int(0.8 * len(X))
print(n)
# Out:
# 353

# %%
x_train = X[:n]
y_train = Y[:n]

# %%
x_test = X[n:]
y_test = Y[n:]

# %%
plt.plot(x_train, y_train, 'g.')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(X, Y, 'g.')

# %%
plt.plot(x_test, y_test, 'r.')

# %%
def hypothesis(a,b,x):
    return a*x**3

# %%
def error(a,b,x,y):
    e = 0
    m = len(y)
    for i in range(m):
        e += np.power((hypothesis(a,b,x[i]) - y[i]), 2)
    
    return (1/(2 * m)) * e

# %%
def step_gradient(a,b,x,y,learning_rate):
    grad_a = 0
    grad_b = 0
    m = len(x)
    for i in range(m):
        grad_a += 1/m * (hypothesis(a,b,x[i]) - y[i]) * x[i]
        grad_b += 1/m * (hypothesis(a,b,x[i]) - y[i])
    
    a = a - (grad_a * learning_rate)
    b = b - (grad_b * learning_rate)
    
    return a, b

# %%
def descend(initial_a, initial_b, x, y, learning_rate, iterations):
    a = initial_a
    b = initial_b
    for i in range(iterations):
        e = error(a, b, x ,y)
        if i % 1000 == 0:
            print(f"Error: {e}, a: {a}, b: {b}")
        
        a, b = step_gradient(a, b, x, y, learning_rate)

    return a, b

# %%
# def descend(initial_a, initial_b, x, y, learning_rate):
#     a = initial_a
#     b = initial_b
#     i = 0
#     while True:
#         e = error(a, b, x ,y)
#         if i % 1000 == 0:
#             print(f"Error: {e}, a: {a}, b: {b}")
        
#         a, b = step_gradient(a, b, x, y, learning_rate)
#         e1 = error(a, b, x, y)
#         if (e1 > e):
#             break
#         i +=1
#     return a, b, i

# %%
a = 0
b = 1
learning_rate = 0.001
iterations = 10000

final_a, final_b = descend(a, b, x_train, y_train, learning_rate, iterations)
# final_a, final_b, iters = descend(a, b, x_train, y_train, learning_rate)
# Out:
# Error: 0.12538927130320496, a: 0, b: 1
# D:\Applications\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in power
#   """
# D:\Applications\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# D:\Applications\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan
# Error: nan, a: nan, b: nan

# %%
print(error(a,b,x_train,y_train))
print(error(final_a, final_b, x_train, y_train))
print(error(final_a, final_b, x_test, y_test))
# Out:
# 0.12538927130320496
# nan
# nan

# %%
plt.plot(x_train, y_train, 'r.', x_train, hypothesis(a, b, x_train), 'g', x_train, hypothesis(final_a, final_b, x_train), 'b', )

# %%
plt.plot(x_test, y_test, 'r.', x_test, hypothesis(final_a, final_b, x_test), 'g')
